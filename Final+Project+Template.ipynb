# %% [markdown]
# <a href="https://colab.research.google.com/github/Endver/AI-at-CCIC/blob/main/Final%2BProject%2BTemplate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Choose a Data Set
#
# You can choose to analyze any data that you would like! Remember, you need 1000 rows of non-null data in order to get 5 points for the "Data" criteria of my [rubric](https://docs.google.com/document/d/1s3wllcF3LLnytxwD8mZ-BCypXKnfaahnizWGNojT-B4/edit?usp=sharing). Consider looking at [Kaggle](https://www.kaggle.com/datasets) or [free APIs](https://free-apis.github.io/#/browse) for datasets of this size. Alternatively, you can scrape the web to make your own dataset! :D
#
# Once you have chosen your dataset, please read your data into a dataframe and call `.info()` below. If you don't call `info` I will give you 0 points for the first criteria described on the [rubric](https://docs.google.com/document/d/1s3wllcF3LLnytxwD8mZ-BCypXKnfaahnizWGNojT-B4/edit?usp=sharing).

# %%
import pandas as pd

df = pd.read_csv("bike_buyers.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1000 non-null   int64
#  1   Marital Status    993 non-null    object
#  2   Gender            989 non-null    object
#  3   Income            994 non-null    float64
#  4   Children          992 non-null    float64
#  5   Education         1000 non-null   object
#  6   Occupation        1000 non-null   object
#  7   Home Owner        996 non-null    object
#  8   Cars              991 non-null    float64
#  9   Commute Distance  1000 non-null   object
#  10  Region            1000 non-null   object
#  11  Age               992 non-null    float64
#  12  Purchased Bike    1000 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 101.7+ KB

# %% [markdown]
# # My Question

# %% [markdown]
# ### Write your question here.
#
# Whats the most common Region the people buy bikes?

# %% [markdown]
# # My Analysis

# %%
# Assuming 'Region' or 'Location' column indicates the region
most_common_region = df['Region'].value_counts().idxmax()
print(f"The most common region for bike buyers is: {most_common_region}")
# Out:
# The most common region for bike buyers is: North America

# %% [markdown]
# people buy bikes most commonly are in urban areas like citys because citys have bike lanes and its a waste of time wairing in traffic with a car perfect example is NYC.

# %%
# Analyze here

# %% [markdown]
# # My Answer

# %%
print(df.columns)
# Out:
# Index(['ID', 'Marital Status', 'Gender', 'Income', 'Children', 'Education',
#        'Occupation', 'Home Owner', 'Cars', 'Commute Distance', 'Region', 'Age',
#        'Purchased Bike'],
#       dtype='object')

# %%
most_common_region = df['Region'].value_counts().idxmax()
print(f"The most common region for bike buyers is: {most_common_region}")
# Out:
# The most common region for bike buyers is: North America

# %% [markdown]
# ### Write your answer here.
#
# The most common region for bike buyers is north america due to the high traffic in the gig citys like New York, Chicago, California, Etc...  .
