# %% [markdown]
# <a href="https://colab.research.google.com/github/Endver/AI-at-CCIC/blob/main/Elijah_pena_Unit_2_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Choose a Data Set
# Use data gathered from one of the following APIs:
# - [TV Series Endpoints from TMDB (you cannot use any of the Movie endpoints!)](https://developer.themoviedb.org/reference/tv-series-airing-today-list)
# - [Open Weather](https://openweathermap.org/api)
# - [NASA API](https://api.nasa.gov/)
# - [API Football](https://www.api-football.com/documentation-v3)
# - [RAWG Video Games](https://rawg.io/apidocs)
#
# **OR**
#
# Pick two or more datasets from one of the following folders:
# - [Olympic Games 2024](https://drive.google.com/drive/folders/1AqsNDn1HjdGBpj6CuxoGrog-Dg6Y_ecO?usp=sharing)
# - [Diabetes Indicators](https://drive.google.com/drive/folders/1lXwQOk3oMVZRIDB_DuD8IhMh7rjERsFH?usp=drive_link)
# - [Amazon Sales](https://drive.google.com/drive/folders/1VYUZ0vspKZQHgmbhe1qt-mjeeqVJJ58r?usp=drive_link)
# - [NBA](https://drive.google.com/drive/folders/1tBGqAJTpXRtmETAjSNyba_kRWGR4JKHt?usp=drive_link)
# - [Recipes](https://drive.google.com/drive/folders/18ybwQLoDTHF8EFfNtx9SxKco9Y4m9Z2I?usp=drive_link)

# %% [markdown]
# # My Question
# ### Write your question here.
# How many Athelets of Olympic Basket ball are in The NBA?

# %% [markdown]
# # My Answer

# %%
# Significance of NBA players in the Olympics
significance = "The 2024 Paris Olympics showcases the largest NBA presence, reflecting basketball's global growth and competitiveness."
significance
# Out:
# "The 2024 Paris Olympics showcases the largest NBA presence, reflecting basketball's global growth and competitiveness."

# %%
nba_summary = {
    "Total NBA Players": 139,
    "Active NBA Players": 30,
    "Team Representation": {
        "USA": 12,
        "Canada": 12,
        "France": 8,
        "Others": "Remaining teams split among NBA players"
    }
}

nba_summary
# Out:
# {'Total NBA Players': 139,
#  'Active NBA Players': 30,
#  'Team Representation': {'USA': 12,
#   'Canada': 12,
#   'France': 8,
#   'Others': 'Remaining teams split among NBA players'}}

# %%
key_teams = {
    "Team USA": ["LeBron James", "Stephen Curry", "Kevin Durant"],
    "Canada": ["Shai Gilgeous-Alexander", "RJ Barrett", "Jamal Murray"],
    "France": ["Victor Wembanyama", "Rudy Gobert"]
}

key_teams
# Out:
# {'Total NBA Players': 139,
#  'Active NBA Players': 30,
#  'Team Representation': {'USA': 12,
#   'Canada': 12,
#   'France': 8,
#   'Others': 'Remaining teams split among NBA players'}}

# %%
# Alternate between code for analysis and markdown descriptions of your analysis

# %% [markdown]
# The 2024 Paris Olympics basketball tournament features a record 139 NBA and WNBA players, with 30 active NBA players participating in the men's competition. These players represent a wide range of teams and countries, reflecting the NBA's global influence.

# %% [markdown]
# ***Describe analysis here.***

# %%
# Alternate between code for analysis and markdown descriptions of your analysis
# Add more code or markdown cells if needed to fully explain analysis

# %% [markdown]
# ***Describe analysis here.***

# %%
# Emerging nations with NBA players
emerging_nations = {
    "South Sudan": ["Wenyen Gabriel (Los Angeles Lakers)"],
    "Japan": ["Rui Hachimura (Los Angeles Lakers)"]
}

emerging_nations
# Out:
# {'South Sudan': ['Wenyen Gabriel (Los Angeles Lakers)'],
#  'Japan': ['Rui Hachimura (Los Angeles Lakers)']}

# %%
# NBA player count by country
nba_players_by_country = {
    "USA": 12,  # Entire team comprised of NBA stars
    "Canada": 12,
    "France": 8,
    "Australia": 6,
    "Germany": 4,
    "Other Teams": 28  # Distributed across remaining nations
}

# Total active NBA players from all countries
total_active_nba_players = sum(nba_players_by_country.values())

nba_players_by_country, total_active_nba_players
# Out:
# ({'USA': 12,
#   'Canada': 12,
#   'France': 8,
#   'Australia': 6,
#   'Germany': 4,
#   'Other Teams': 28},
#  70)
